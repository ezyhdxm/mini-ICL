# %%
import torch
from icl.figures.task_vec_viz import *
from tqdm.notebook import tqdm, trange

import plotly.io as pio
pio.renderers.default = "notebook_connected"

from icl.coin.coin import * 
from icl.coin.coin_config import get_config_coin
from icl.figures.attn_plots_beta import visualize_attention
from icl.utils.train_utils import get_attn_base, compute_cross_entropy, ih_score, get_attn_at_layer_base
from icl.figures.head_view import *
from icl.utils.latent_task_vec import *
from icl.utils.coin_ood_analysis import get_new_sampler
import icl.utils.notebook_utils as nu
from icl.utils.unified_interface import get_exp_name, unified_train
from icl.utils.unified_plot import get_var_plot, projection_plot, traj_projection_plot
from icl.utils.unified_ood_analysis import process_ood_minor_metric, plot_training_curves_all_experiments

torch.set_printoptions(precision=3, sci_mode=False)

# %load_ext autoreload
# %autoreload 2

# %%
train_results = unified_train("coin", -1, vocab_size=13)

# %%
exp_name = get_exp_name("coin", 10, vocab_size=13)
traj_projection_plot("coin", exp_name, n_minor = 6, n_ood = 6, layer_index=5)

# %%
exp_name = get_exp_name("coin", 0, log2=False, vocab_size=13)
traj_projection_plot("coin", exp_name, n_minor = 0, n_ood = 12, layer_index=5)

# %%
exp_name = get_exp_name("coin", -1, vocab_size=13)
traj_projection_plot("coin", exp_name, n_minor = 0, n_ood = 60, layer_index=5)

# %%
_, sampler, _ = nu.load_everything("coin", exp_name)
sampler.major_p
# Out:
# tensor([[0.248, 0.001, 0.001, 0.001, 0.248, 0.001, 0.001, 0.001, 0.248, 0.248,
#          0.001, 0.001],
#         [0.001, 0.001, 0.248, 0.001, 0.001, 0.248, 0.001, 0.248, 0.001, 0.001,
#          0.001, 0.248],
#         [0.001, 0.248, 0.001, 0.248, 0.001, 0.001, 0.248, 0.001, 0.001, 0.001,
#          0.248, 0.001]], device='cuda:0')

# %%
from icl.utils.attention_scores import get_attn_map
from icl.utils.attn_plots import ( 
    visualize_attention_with_head_view, 
)

#attn_map, batch = get_attn_map(task_name="coin", k=12, step=60_000)
#visualize_attention_with_head_view(attn_map, batch, max_tokens=81)

# %%
exp_name = get_exp_name("coin", 10, 13)
get_var_plot("coin", exp_name)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
steps = list(range(0, 2001, 50))
for k in trange(2, 11, 2):
    exp_name = get_exp_name("coin", k, vocab_size=13)
    results = process_ood_minor_metric(
        task_name="coin",
        exp_name=exp_name,
        steps=steps,
        force_recompute=False
    )
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
figs = plot_training_curves_all_experiments(
        "coin",
        list(range(150, 2001, 50)) + list(range(4000, 60001, 2000)),
        list(range(2,11,2)), 
        metric="maj_r2_ood",
        layer_index=5,
        vocab_size=13,
        )
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
figs = plot_training_curves_all_experiments(
        "coin",
        list(range(150, 2001, 50)) + list(range(4000, 60001, 2000)),
        list(range(2,11,2)), 
        metric="min_r2_ood",
        layer_index=5,
        vocab_size=13,
        )
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
