# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colorbar as colorbar
import matplotlib.colors as mcolors
import matplotlib.patches as patches
import torch.utils.benchmark as benchmark
from icl.figures.task_vec_viz import *
from tqdm.notebook import tqdm, trange
import os

import plotly.io as pio
pio.renderers.default = "notebook_connected"
import plotly.graph_objects as go

import copy

from icl.utils.train import train_model_with_plot
from icl.coin.coin import * 
from icl.coin.coin_config import get_config_coin
from icl.models import Transformer
from icl.figures.attn_plots_beta import visualize_attention
from icl.utils.train_utils import get_attn_base, compute_cross_entropy, ih_score, get_attn_at_layer_base
from icl.figures.head_view import *
#import icl.utils.task_vec as task_vec
from icl.utils.latent_task_vec import *
#from icl.utils.fast_latent_task_vec import compute_hiddens_onepos_all_layers_fast
import icl.utils.notebook_utils as nu
from icl.utils.ultra_latent_task_vec import compute_hiddens_onepos_all_layers_ultra
from icl.utils.kv_latent_task_vec_beta import compute_hiddens_onepos_all_layers_kvcache_beta
# from icl.utils.fast_latent_task_vec_kvcache import compute_hiddens_onepos_all_layers_kvcached
torch.set_printoptions(precision=3, sci_mode=False)

# %load_ext autoreload
# %autoreload 2

# %%
config = get_config_coin()
config.training.warmup_steps = 10_000
config.training.num_epochs = 20_000
config.vocab_size = 4
for k in range(1, 10, 2):
    config.task.n_minor_tasks = 2**k
    model = Transformer(config)
    model = model.to(config.device)
    train_results = train_model_with_plot(model, config, show=False, verbose=False)
# Out:
# Experiment directory:  ..\results\coin\train_3f17a09db4719418877265b9a8582ab3
# train_3f17a09db4719418877265b9a8582ab3 already completed
# Experiment directory:  ..\results\coin\train_7599f2078faa51921b8aff140db931c1
# train_7599f2078faa51921b8aff140db931c1 already completed
# Experiment directory:  ..\results\coin\train_cd0cdd990ac9b3b8e1a0c83b1f486bdb
# train_cd0cdd990ac9b3b8e1a0c83b1f486bdb already completed
# Experiment directory:  ..\results\coin\train_de294a0cd8f599e46f1886de966bcbe7
# train_de294a0cd8f599e46f1886de966bcbe7 already completed
# Experiment directory:  ..\results\coin\train_02221ecdf0b6a4c1ddd41a5ae61ef3f9
# train_02221ecdf0b6a4c1ddd41a5ae61ef3f9 already completed

# %%
exp_name = "train_02221ecdf0b6a4c1ddd41a5ae61ef3f9"
model, sampler, config = nu.load_everything("coin", exp_name)

def get_new_sampler(exp_name, n_tasks=61, n_ood=40, B=96):
    model, sampler, config = nu.load_everything("coin", exp_name)
    sampler_clone0 = copy.deepcopy(sampler)

    orig = sampler_clone0.minor_p
    if orig is None:
        raise ValueError("sampler.minor_p is None; cannot expand minor pool.")

    # How many OOD rows we must insert up front
    # (ensures at least n_ood, and also enough room so we can reach n_tasks total)
    k_ood = max(n_ood, n_tasks - sampler_clone0.n_minor_tasks)

    sampler_clone0.n_minor_tasks = n_tasks
    k_minor = n_tasks - k_ood  # how many "old" rows we want after the OOD block

    n_orig = orig.shape[0]
    trailing_shape = orig.shape[1:]  # () for Bernoulli-style, (K,) for categorical, etc.

    # --- build OOD rows with matching shape/dtype/device ---
    # raw random
    ood = torch.rand((k_ood, *trailing_shape), device=orig.device, dtype=orig.dtype)

    # If categorical/multinomial probs, normalize over the last dim
    # (assumes last dim represents states)
    if orig.ndim >= 2:
        ood = ood / ood.sum(dim=-1, keepdim=True).clamp_min(1e-12)

    # --- allocate new minor_p ---
    new_minor = orig.new_empty((n_tasks, *trailing_shape))  # same dtype/device

    # Fill first k_ood with new OOD
    new_minor[:k_ood].copy_(ood)

    # Fill remaining with old minors (as many as we actually have)
    take = min(k_minor, n_orig)
    if take > 0:
        new_minor[k_ood:k_ood + take].copy_(orig[:take])

    # If we still need more rows (old pool too small), generate additional random rows
    remain = k_minor - take
    if remain > 0:
        extra = torch.rand((remain, *trailing_shape), device=orig.device, dtype=orig.dtype)
        if orig.ndim >= 2:
            extra = extra / extra.sum(dim=-1, keepdim=True).clamp_min(1e-12)
        new_minor[k_ood + take:].copy_(extra)

    sampler_clone0.minor_p = new_minor
    return sampler_clone0, k_minor

# %%
sampler_clone0, k_minor = get_new_sampler(exp_name, n_tasks=61, n_ood=40, B=96)
hiddens = compute_hiddens(config, model, sampler_clone0, layer_index=5, return_final = False)
plot_task_vector_modes(hiddens[:3])
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="911c71e0-02cc-4681-8346-1babb596ece4" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("911c71e0-02cc-4681-8346-1babb596ece4")) {                    Plotly.newPlot(                        "911c71e0-02cc-4681-8346-1babb596ece4",                        [{"line":{"width":1},"mode":"lines","name":"Task 0","opacity":0.5,"visible":true,"x":{"dtype":"i2","bdata":""},"y":{"dtype":"f4","bdata":"IPsSPs1CDT76Kwc+iA4APqDJ9z0oZPU9Ga3sPfiJ2T0mdss9Yse+PYupqT3Dw6M9OyiiPe5YnD2fY5w9kOGePbZ\u002foD3GI5o9yrKVPfxKmD1WsIw96XOCPZ63aT2wsmg9w0tYPcPeRj3f+TQ9UpsyPQJ7LT3E\u002fzA9FrolPQ4EGj0G3Q09JosMPQ6YCj3ykwk9JCIJPSZBBT0Jzgg9YE4HPcXLBj0vvQE9yZDtPFot9TxG++o8evPgPM7g1jy9z9Q8iEbMPBnbyzws4sU8ZHu+POx0uzw7Hrg8xRy1PHIbsjxTRbI8YDSyPJugrzza+qo8pF2pPFZ3qzzZDKw8qWWrPCm9rDwn\u002f6g8+QmpPMYFrjx2ua083lipPJ4vpTz0bKI8dK2jPA9BoDxrtpw8IfuaPERSmDzjd5g8Qw+XPGjdkzx0d5M8rP6VPFAYljxGQ5I83peSPPeajjzcX5A8+UyQPKHJkTxIe5I8SJKUPGq0kzwSPpE8bg2OPP6NijzKrI48LBGNPIjGjDyKhZA85K+NPGDojDxAWpE8b3GOPHqUjzyQ1Y48wi6MPLx1jDzYMIs8oiGJPE2\u002fhzw6b4g81vWFPIhvhDxUQ4M8bduAPO5rfzxAYnk80B97PAI3djwwzG48GlpqPFBwajwZdGY8WSFkPDFIYzwGJGQ8AJ9hPKjgXTw="},"type":"scatter"},{"line":{"width":1},"mode":"lines","name":"Task 1","opacity":0.5,"visible":true,"x":{"dtype":"i2","bdata":""},"y":{"dtype":"f4","bdata":"DCdJPgIGWj5lUEg+voo\u002fPnwTKz7CUTA+17ksPvBdKz64vCI+mg4UPhy8BD4sTwE+ml39PcPq4j0QseI90LDUPX63vD1iNrE98R+mPd5+mj2qqps9GnufPehLlT3475I9PuKLPeawhj2H9ns9qMRxPZhWcz2t\u002fHI9159mPWZYYD0cpVU9ZoRYPcuySz1LhUg9GFxBPUoQNj3wAjM9uLcuPSmxLT0EpiE9HxUgPYS2HD00vh09AvAaPTrBFz2F3hU9rRwXPWwkFD2OvRI9rL0QPagwDT1aaww9ChgJPTaeAz1cC\u002fg8ULLwPOZZ6jzIfO08MKjqPIVM7DzQz+48v+rsPNiY7TyEuPU8\u002fGT3PKL95zygn+o8hs\u002flPOYL5DzD2tw8nAvXPB5C0jwmA9I8BTrRPNZb0DySpMw8K+PPPIyMyTxNZ8g8jtnIPPlKxTzaCcY8umHEPJQ9vjwMU8A82rS9PPiAvTzAYbw8cqS5PPyotDxPDbQ8ZXa5PNBZuTxIubs8KgS\u002fPIQgvjxqGb88VjS+PMYatzxcY7M8Zhq0PK3Asjz+T7Q8yPWuPLoBqjyUmqg8ZrWkPMbFoTyYOp88cGGgPAbLnzxQ7Jc8fnqWPIUYljxatpc85mOWPBtomjzGWpw8Um6bPLqOnDwHXZo8X2mXPEIHlTy+vZA8MdWOPNu\u002fizw="},"type":"scatter"},{"line":{"width":1},"mode":"lines","name":"Task 2","opacity":0.5,"visible":true,"x":{"dtype":"i2","bdata":""},"y":{"dtype":"f4","bdata":"j+MqPrDrNj6kaRo+8KAUPuouCz69awc+bREEPlLg9D3e5us9YJbaPXacyz3uXbM9z5OgPZH9lT2p0Y89ax+HPSw9dz2G2nc9zmdkPQjxTj2Ug0k9JJBLPUdJTT1skEE9t50\u002fPboDPT3IBj89VGc0PS31Kz2oSio9VFQdPVg3HT285h09mB4aPaCWFz0Tuxo9QLAaPYuGGD1E\u002fxU9vB0PPYraDD02twc9q3gDPda5BD25n\u002fk8qvT8PBpz\u002fDwy7\u002f885UABPdob\u002fzzOhPs8sIz1PP+w7TzUruM8nJPfPJg+2Dwe\u002fdk8DA\u002fUPIQXzzzAjck8M+nDPDCqwzwOSsc8lwvDPDVrwDzB27Y8qwyvPKtXqDzmxaU87e6qPJy+qjzXgqs8n7qkPHRwqDyc4qM8MqGgPNxBoDyR5588vEaePGHf ...

# %%
from icl.linear.linear_utils import estimate_lambda_with_r2

# We concatenate all hidden representations for different vocabularies together and then do the projection.
def plot_hidden_proj(hiddens, k_minor):
    # (n_tasks, seq_len-1, B, n_embd)
    global_mean = hiddens[:3].mean(dim=(0,2)) # (T, D)
    task_vecs_over_all_time = hiddens.mean(dim=2) - global_mean.unsqueeze(dim=0) # (K, T, D)
    final_task_vecs = task_vecs_over_all_time[:3, -1]
    lambdas_voc_mlp0, r2_scores, task_norms, ortho_norms = estimate_lambda_with_r2(final_task_vecs, task_vecs_over_all_time)
    fig = project_with_r2_size(
        task_vecs_over_all_time, 
        final_task_vecs, 
        r2_scores, 
        lambdas_voc_mlp0, 
        n_minors=k_minor,
        hover_data=torch.concat([sampler_clone0.major_p, sampler_clone0.minor_p]), 
        hover_name="p",
        )
    fig.show()

plot_hidden_proj(hiddens, k_minor)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="b1b86a62-ba0e-432c-8915-edca90beb45b" class="plotly-graph-div" style="height:650px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b1b86a62-ba0e-432c-8915-edca90beb45b")) {                    Plotly.newPlot(                        "b1b86a62-ba0e-432c-8915-edca90beb45b",                        [{"customdata":{"dtype":"f4","bdata":"qXNEP2iutj4Z7lg+i9rcPnHI3z3\u002fPBs\u002f5ZORPjZkOj8E340+wsQWP\u002fMuCT5RBC4\u002fDRO9PTllaT4Gey4\u002fjnK7PuX+Sz4Djt4+GrFTPTEuFT95Lbs+","shape":"3, 7"},"hovertemplate":"task=%{text}\u003cbr\u003eR²=%{customdata[0]:.3f}\u003cbr\u003eλ₁=%{customdata[1]:.3f}\u003cbr\u003eλ₂=%{customdata[2]:.3f}\u003cbr\u003eλ₃=%{customdata[3]:.3f}\u003cbr\u003ep_0=%{customdata[4]:.3f}\u003cbr\u003ep_1=%{customdata[5]:.3f}\u003cbr\u003ep_2=%{customdata[6]:.3f}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"blue","opacity":0.8,"size":{"dtype":"f4","bdata":"mvKFQdiLgUGlq3hB"},"sizemode":"diameter"},"mode":"markers","name":"major tasks","text":["item_0","item_1","item_2"],"x":{"dtype":"f4","bdata":"uD4nwHU\u002fr0A4QDfA"},"y":{"dtype":"f4","bdata":"pkW5PaafJ77i+ZU9"},"type":"scatter"},{"customdata":{"dtype":"f4","bdata":"ktRFPxlUnz4U4OY+qpdzPtzLCz8cc0c+ua6EPmSfEj8Cv6o+1UzXPlDoez4GJM0+qiigPedoBT8AAAAAzOy3PjYmpz7\u002f7KA+SfVjPlryLz4YBhs\u002feZMcP8ZBqz6eIYc+npzNPgDeSj4b6iU\u002fmHkdPgAAAADVSLA+FlqmPhRdqT4PjmI+Qn6kPrY66j4StkA\u002faCupPq\u002f9sT7q1qQ+j52sPkRNzT4uFYY+8oJEP77ptj4iZlY+MOPdPhr6kj1oURw\u002fqp6iPjDyOj\u002fpMJ8+Wx\u002ffPr2vgT5GH9Y+52ukPtR0hT5Q9mA9\u002fL61PogWnD58Kq4+9Bo+PkQYlj4hbQU\u002fAAAAAEacpz4EWao+tAquPnymkz4kheY+X9SFPunaQj\u002f7h7A+et5ePssI4D6FnvU9sKUvP\u002f2ZRj7ojUo\u002f7ru0PspGQD6uIOs+NpHDPTrLMz98Ck8+NmgePwxUlj6wJ\u002fU+hwhpPgkSET+14JM+dvYTPriBSj9zFrE+zFqDPsOOyz6+weA9LoETPzXNoD6ESjw\u002foRiZPokm\u002fD6sgVU+cwMMP40oeD6hyVc+cIvdPhNWoj5mC8I+iJ6bPjg22D7Ey74+B\u002fxRPqafGj9+G6o+kK\u002fVPvQ0gD69occ+wA7wPZRa\u002fD5+i0U\u002f1XCcPvzK9T5eiFs+jBsDP7hnXz4NFYo+4GdFPwEBqD7raMM+FJaUPlTXpT6RHaI+Ggu4PjCK3z4ft6k+byedPnIhuT4Cx20+ky0BP1vBhj4gl7M9Xm+zPginnT6Y6a4+q3xwPudvnz7DUeg+tPc\u002fP84Kjz6WPxg\u002fC+wAPv6ZQj85wzM9PqdIPni+qT1my7U+2zzBPr\u002f3iD7fD6A+CyQjPdDFJT\u002fCa0Q\u002fft6SPvbmEj8upw4+VsYrPxS1jT0SBoU+QyZLP3ANsj7FXnU+LkPTPhQ5PD4f1xk\u002fcGpcPlsJSj8E2LA+Zap2Ps7S0z66WhE+hOMXP5yLhz7mn0k\u002fqGGmPsxEzD6MWY0+skfGPiKUgj4rJLc+AAAAAPJbtj7emKo+MAufPgAPVD5m810+Z38TP6xmBz9eBL8+eO5SPmiE1z76NyU9kAjsPnFQ\u002fz7AANU9gMekPrbasz7LXac+7kGjPmx05z5Hk2o+7OvZPmaZvz51+2A+4ujPPt2zMz38TeM+xB0DP5RtQT9cfKI+tBXTPvNtij6Eycw+Xu6hPh5IkT4AAAAAxPimPsC7qD5\u002fS7A+x5OIPtjMGD8YpQs+EksSP8vyvj68LUs+WnbbPmdJOjx5C+s+HpEHPzzzSj\u002fkB54+v3UCPz8ZOj6MyAs\u002freecPQA1wT5E+5Q+nvqYPtwf0z6I5ZM+4ZDwPt6U+T4S0i49PDSNPvZUmj5yI88+mYeWPpqj7j70M\u002fc+jUNRPUAWDD+Qso0+BPYEP9DCUD6\u002fviI\u002fbxS1PmPCLTymSuw+tWerPiSktz4o9Jw+sz+KPqn0nj6ky9Y+ECELP+LtjT4HVAQ\u002fItRSPumoGD\u002fp\u002fcU+MASLPFQs2T7jiaA+CsLGPhW0mD6rM8Q+PGvmPjTCKj7YKJE9ceWmPrXyrz7aJ6k+DVeePgSZ\u002fT7fH0g+AAAAAFpnoT5uurI+Ot6rPuIwwz7AD\u002f8+fP32PVgqlj4harU+UP6RPo+XuD5F\u002f1A+OhikPiNo8z6wfhM9mw64PgeGmj5ea60+l7hKPuIcez6hig4\u002fqopEP0Ilpz41Wcw+iIGMPt7Nvj7mmXs+MGXDPvpF1D4j960+JHrSPnQdfz5FacA+Ked6PeocED\u002fWdRc\u002fcUq+Pq2OSz477ts+KfG4PEF3BD9rgus+RCsSPqE8tD73H5o+aKOxPiIscj5136I+ewrkPih4rj1VwKI+Gl2aPpDiwj7qhXY+ntM+Pwa6YjywwZA+FiCdPjw9yT6wopk+wjQEP5O20D6df5s9ZkArP+dgqD6PRt4+FrFyPjUJ2z60yLs9nQT2Pibc0T71q5g+zprbPj65iz6MbfI+ypTsPqz2gz3WESI\u002fFGOGPi9YGT8c2Q0+vEE7P146gT6oIoQ8omvNPtgsnT5W684+1OeTPk9r7D7JC+E+miPKPYh++D6FXbs+cptwPsJUzD5s\u002f749d6\u002fkPq2Q6z7jvjg\u002ftpSmPjP94j4w3Gw+0b\u002fcPhdyHz4jh9M+HP4RPzccnz5q9dE+YO6OPulc1D7F7sU+omhLPjoj4D7ITJc+9GThPkROhz4oyAA\u002f33LnPpnmNz0=","shape":"59, 7"},"hovertemplate":"task=%{text}\u003cbr\u003 ...

# %%
plot_hidden_proj(hiddens, k_minor)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="b3901534-1665-4030-b545-cebe1631765b" class="plotly-graph-div" style="height:650px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b3901534-1665-4030-b545-cebe1631765b")) {                    Plotly.newPlot(                        "b3901534-1665-4030-b545-cebe1631765b",                        [{"customdata":{"dtype":"f4","bdata":"aNwoP9XsAT+PAI8+j0taPpIDMD8mffM8B8GQPo4BzT7EMZg+R9jCPvb1pD59V50+5dsVPkjdCz+rgSk\u002fJOlHPicnrj5I5O0+vEc5PSfd6D7h+f8+","shape":"3, 7"},"hovertemplate":"task=%{text}\u003cbr\u003eR²=%{customdata[0]:.3f}\u003cbr\u003eλ₁=%{customdata[1]:.3f}\u003cbr\u003eλ₂=%{customdata[2]:.3f}\u003cbr\u003eλ₃=%{customdata[3]:.3f}\u003cbr\u003ep_0=%{customdata[4]:.3f}\u003cbr\u003ep_1=%{customdata[5]:.3f}\u003cbr\u003ep_2=%{customdata[6]:.3f}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"blue","opacity":0.8,"size":{"dtype":"f4","bdata":"28BzQa6wOUF2UXRB"},"sizemode":"diameter"},"mode":"markers","name":"major tasks","text":["item_0","item_1","item_2"],"x":{"dtype":"f4","bdata":"Rk48wNK+fj5cYixA"},"y":{"dtype":"f4","bdata":"LvHTPrPluL6fW1i9"},"type":"scatter"},{"customdata":{"dtype":"f4","bdata":"CKXFPiWIvD4b0UU+To\u002fgPgF\u002frj7meew+Mw5KPjzr0z5wF+E+YZ9MPt+YuD6H4Qk\u002f\u002fHKQPumTNz4kZ9I+21W2PhyEUD4XaOE++Q65PtxQ+D5YQB0+0EHQPlMshT4EyNo+rAugPvJ7ZD7f9wM+DOMlP+7mBD+tG48+IHeVPUjDJT9YY\u002fw96GdRP9q6cD1dvSk\u002f1Z3IPks8pD7hJZM+h7n0Pn2vFj657r8+HGAoPziW8T45gJI+I9N3PnPJID+M3JE99PWZPlA+IT9YWmA+of2JPpvqAj9KCpU9WFroPhZj8j5kcxc\u002fSYLTPgBWjT64J58+7CjqPsVKTj6wsa4+mqgeP5reZD7WwIE+8OcFP+HikT2+b\u002fg+ihfjPlayKT\u002f6Z4c+DJutPvr8yj7LXEQ+iP2nPhPU9T6kXRg\u002fyLBtPkA7WT4ARQ4\u002fP2VlPU2aIT+9HqA+IpwpP9jNVT5L564+yjHmPqz7fD0Asc4+xtcIP0tKJT\u002f8clE+jN2WPn40AD8QEEc9rEn0PlHU8j6kRx8\u002fT3C9PimMtz6JA4s+UoTrPgcriD3scPI+dnYlP8arDD+QTnA+VwJdPnhKUD+LOXY9vkcBPlwnJj\u002foiT0+jECYPkF9BD9KhZg60E7oPlWMCz++qB4\u002f7VDoPvkvhT4af5I+9JUWP+UKCT6mTo4+qnMhP6qHUT5FuoY+9EAIPxcJoTzryfY+gyX\u002fPh6kKT+2Qns+2+qtPstz1D4rF+Q9aUiEPuZYIT8eVK4+kOuyPps4lz7X27U+qw7DPjBIhz4lqbU+3XcNP7MWoT4I1ZI+RxTMPpjKjz6LaYw+3MvjPpR1sT6nKbs+EU+APkuHxD6hZak+wLu2Pp7enz7KsAU\u002f7BLpPst\u002fYT4uLaY+Q6kOP2Y3hD4o7Dw+9CMoPx8Fvz7meKM++4GdPi\u002fa0j6yajU+d3DSPhKGrT6yktY+SPgLPi5x4z6lr\u002fw+tTziPpNOhD2umMo+Xc7gPopyRT5eeLw+WKwFP25iqz7HiRI+KqPHPirQ7j7oshw+Y9bCPhNIAj\u002f\u002f+N0+8LZrPeSwqz4PMrs+grWKPm8Yuj4fx9s+T0mBPpHvoj5gtiQ\u002fZqRkPu6glz7fDPY+8gHAPcYV9D6\u002f6ds+AZYJPxPskT6IwjI+VVkKP8ugYD5USgw\u002f6DVuPrD6qz6Ox9Q+THghPkx82j5g9fE+M1XWPqvV3j3mXNA+4g6wPhzijT4GD8I+jufBPh0jmT5W9aQ+srspP9BgzT5mfKc+yyKLPkBECT8Nv8s9vYe6PpoJxz4HOLU+ErF9Pm\u002fvyz6k07c+\u002fHCuPmG7mT7CuQY\u002fZt+cPjOjYz4CT\u002fE+Dxl5Ph1k7j5ZD5U+WKEXPw4OcD4SqFU+eJIOP5lUmj2f2hk\u002fm7WlPgBfFz+kfs4+7OWQPnKboD5AIgU\u002fxfdAPp0\u002flT6aXRM\u002f0wdjPgK+1j4Wvrc+ouzEPYI6Zj7L0y0\u002f\u002fvseP8zEyj7gVZc+VOWdPuRpAD+4LzQ+XRSlPg==","shape":"40, 7"},"hovertemplate":"task=%{text}\u003cbr\u003eR²=%{customdata[0]:.3f}\u003cbr\u003eλ₁=%{customdata[1]:.3f}\u003cbr\u003eλ₂=%{customdata[2]:.3f}\u003cbr\u003eλ₃=%{customdata[3]:.3f}\u003cbr\u003ep_0=%{customdata[4]:.3f}\u003cbr\u003ep_1=%{customdata[5]:.3f}\u003cbr\u003ep_2=%{customdata[6]:.3f}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"green","opacity":0.8,"size":{"dtype":"f4","bdata":"NHg2Qeq2PEEgDTxByxw7QRBKVEGxhXRBGFRzQYYWbUH4hGRBh9NqQQt8dEHwUWVBnmh0QQKhcEGwXmtBp8dwQXBicUGm02pBNUVtQZpvdEHNRCxB4shbQXGjLUGx+lRBdh9zQajqK0HMojhBYlc3QWQdK0GUH3BBQWNYQa09K0GkKDtBPIR0QTQUN0GK4lVBLa1kQSBzZEHn8WBBfhxrQQ=="},"sizemode":"diameter","symbol":"square"},"mode":"markers","name":"OOD tasks","text":["item_3","item_4","item_5","item_6","item_7","item_8","item_9","item_10","item_11","item_12","item_13","item_14","item_15","item_16","item ...

# %%
import json
import plotly.graph_objects as go

def plot_eval_losses(exp_name, exp_group="coin", step_range=None):
    """
    Plot eval/IDLoss and eval/OODLoss against training steps.
    
    Args:
        exp_name: Experiment name (e.g., "train_6b9b1e239ad66222ef2361ad413c390b")
        exp_group: Experiment group directory (default: "coin")
        step_range: Tuple of (min_step, max_step) to filter steps. If None, plots all steps.
    """
    log_path = f"../results/{exp_group}/{exp_name}/log.json"
    
    try:
        with open(log_path, 'r') as f:
            log_data = json.load(f)
        
        eval_steps = log_data["eval/step"]
        id_loss = log_data["eval/IDLoss"]
        ood_loss = log_data["eval/OODLoss"]
        
        # Filter steps if range is provided
        if step_range is not None:
            min_step, max_step = step_range
            filtered_indices = [i for i, step in enumerate(eval_steps) if min_step < step <= max_step]
            eval_steps = [eval_steps[i] for i in filtered_indices]
            id_loss = [id_loss[i] for i in filtered_indices]
            ood_loss = [ood_loss[i] for i in filtered_indices]
        
        # Create figure
        fig = go.Figure()
        
        # Add ID Loss
        fig.add_trace(go.Scatter(
            x=eval_steps,
            y=id_loss,
            mode='lines',
            name='eval/IDLoss',
            line=dict(width=2)
        ))
        
        # Add OOD Loss
        fig.add_trace(go.Scatter(
            x=eval_steps,
            y=ood_loss,
            mode='lines',
            name='eval/OODLoss',
            line=dict(width=2)
        ))
        
        # Update layout
        fig.update_layout(
            title=f'Evaluation Losses over Training Steps<br>Experiment: {exp_name}',
            xaxis_title='Training Step',
            yaxis_title='Loss',
            hovermode='x unified',
            template='plotly_white',
            width=1000,
            height=600,
            legend=dict(x=0.02, y=0.98)
        )
        
        return fig
        
    except FileNotFoundError:
        print(f"Could not find log file at {log_path}")
        return None
    except KeyError as e:
        print(f"Missing key in log data: {e}")
        return None
    except Exception as e:
        print(f"Error loading eval losses: {e}")
        return None

# Example usage:
fig = plot_eval_losses(exp_name, exp_group="coin")
if fig:
    fig.show()

# With step range filter:
# fig = plot_eval_losses(exp_name, exp_group="coin", step_range=(300, 30000))
# if fig:
#     fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="c81f2fbd-bf96-4fd8-b5ed-705a174272a1" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c81f2fbd-bf96-4fd8-b5ed-705a174272a1")) {                    Plotly.newPlot(                        "c81f2fbd-bf96-4fd8-b5ed-705a174272a1",                        [{"line":{"width":2},"mode":"lines","name":"eval\u002fIDLoss","x":[5,10,15,20,25,30,35,40,45,50,100,150,200,250,300,350,400,450,500,550,600,650,700,750,800,850,900,950,1000,1050,1100,1150,1200,1250,1300,1350,1400,1450,1500,1550,1600,1650,1700,1750,1800,1850,1900,1950,2000,2050,2100,2150,2200,2250,2300,2350,2400,2450,2500,2550,2600,2650,2700,2750,2800,2850,2900,2950,3000,3050,3100,3150,3200,3250,3300,3350,3400,3450,3500,3550,3600,3650,3700,3750,3800,3850,3900,3950,4000,4050,4100,4150,4200,4250,4300,4350,4400,4450,4500,4550,4600,4650,4700,4750,4800,4850,4900,4950,5000,5050,5100,5150,5200,5250,5300,5350,5400,5450,5500,5550,5600,5650,5700,5750,5800,5850,5900,5950,6000,6050,6100,6150,6200,6250,6300,6350,6400,6450,6500,6550,6600,6650,6700,6750,6800,6850,6900,6950,7000,7050,7100,7150,7200,7250,7300,7350,7400,7450,7500,7550,7600,7650,7700,7750,7800,7850,7900,7950,8000,8050,8100,8150,8200,8250,8300,8350,8400,8450,8500,8550,8600,8650,8700,8750,8800,8850,8900,8950,9000,9050,9100,9150,9200,9250,9300,9350,9400,9450,9500,9550,9600,9650,9700,9750,9800,9850,9900,9950,10000,10050,10100,10150,10200,10250,10300,10350,10400,10450,10500,10550,10600,10650,10700,10750,10800,10850,10900,10950,11000,11050,11100,11150,11200,11250,11300,11350,11400,11450,11500,11550,11600,11650,11700,11750,11800,11850,11900,11950,12000,12050,12100,12150,12200,12250,12300,12350,12400,12450,12500,12550,12600,12650,12700,12750,12800,12850,12900,12950,13000,13050,13100,13150,13200,13250,13300,13350,13400,13450,13500,13550,13600,13650,13700,13750,13800,13850,13900,13950,14000,14050,14100,14150,14200,14250,14300,14350,14400,14450,14500,14550,14600,14650,14700,14750,14800,14850,14900,14950,15000,15050,15100,15150,15200,15250,15300,15350,15400,15450,15500,15550,15600,15650,15700,15750,15800,15850,15900,15950,16000,16050,16100,16150,16200,16250,16300,16350,16400,16450,16500,16550,16600,16650,16700,16750,16800,16850,16900,16950,17000,17050,17100,17150,17200,17250,17300,17350,17400,17450,17500,17550,17600,17650,17700,17750,17800,17850,17900,17950,18000,18050,18100,18150,18200,18250,18300,18350,18400,18450,18500,18550,18600,18650,18700,18750,18800,18850,18900,18950,19000,19050,19100,19150,19200,19250,19300,19350,19400,19450,19500,19550,19600,19650,19700,19750,19800,19850,19900,19950,20000],"y":[1.4607200622558594,1.3002501726150513,1.1595929861068726,1.0398383140563965,0.9399805068969727,0.8571621775627136,0.7887779474258423,0.7333360910415649,0.6881628632545471,0.6515339016914368,0.492568701505661,0.45565885305404663,0.445420503616333,0.44076982140541077,0.4382879137992859,0.4367329478263855,0.43561670184135437,0.4346597492694855,0.43409883975982666,0.43359702825546265,0.43306827545166016,0.43274304270744324,0.43233340978622437,0.4323083758354187,0.4323059320449829,0.4318932890892029,0.4316718876361847,0.4316512644290924,0.4320465624332428,0.4314735531806946,0.4313662350177765,0.43132156133651733,0.43134546279907227,0.4311201274394989,0.4312674105167389,0.4310905933380127,0.431292861700058,0.4310249984264374,0.4310729503631592,0.43094250559806824,0.4309499263763428,0.43081092834472656,0.4311540126800537,0.43094906210899353,0.43062061071395874,0.43088966608047485,0.4312836229801178,0.431147038936615,0.4306615889072418,0.43057042360305786,0.430980920791626,0.43031641840934753,0.4303475022315979,0.43035662174224854,0.4302331805229187,0.43000221252441406,0.430835485458 ...
