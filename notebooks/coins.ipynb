# %%
import torch
torch.set_printoptions(precision=3, sci_mode=False)

# %load_ext autoreload
# %autoreload 2

# %%
from icl.utils.unified_interface import unified_train

task_name = "coin"
for k in range(-1, 15):
    results = unified_train(task_name, k=k)

# %%
from icl.coin.coin_analysis import plot_coin_task_posterior
from icl.utils.unified_interface import get_exp_name

# Get experiment name for a non-padded coin experiment (pad="none" is the default)
exp_name = get_exp_name("coin", k=12)

# Plot task posteriors for 3 random samples
info = plot_coin_task_posterior(
    exp_name,
    n_plots=3,
    max_positions=120,
    major_only=True,
)

# Access the posteriors programmatically if needed
# info['posteriors'] is a list of (seq_len, n_tasks) tensors, one per sample
# info['fig'] and info['axes'] give you the matplotlib objects

# %%
from icl.coin.coin_analysis import plot_p1_variance_coin
from icl.utils.unified_interface import get_exp_name

exp_name = get_exp_name("coin", 3)

results = plot_p1_variance_coin(
    exp_name,
    layers=range(2, 6),
    batch_size=32,
    n_minor=8,
    verbose=False,
    log_x=False,
)

# %%
from icl.coin.coin_analysis import plot_task_variance_coin

exp_name = get_exp_name("coin", 3)

results = plot_task_variance_coin(
    exp_name,
    layers=range(2, 6),
    batch_size=64,
    n_minor=8,       # capped at sampler's actual count
    verbose=True,
    log_x=False,
)
# Out:
# 2026-03-02 22:13:01 - icl.coin.analysis.variance - INFO - Computing task variance for coin exp: train_935e149d242e83aa823ddc34f75d8d7e
# 2026-03-02 22:13:01 - icl.coin.analysis.variance - INFO - Layers: range(2, 6), B: 64, n_tasks: 11 (k_minor=8)
# 2026-03-02 22:13:02 - icl.coin.analysis.variance - INFO - Hiddens shape: torch.Size([4, 11, 127, 64, 128]). Computing task variance...
# 2026-03-02 22:13:02 - icl.coin.analysis.variance - INFO - Computed variance for 4 layers

# %%
from icl.coin.coin_analysis import plot_id_ood_loss_coin

out = plot_id_ood_loss_coin(
    k_list=range(0, 15),
    logx=True,
    figsize=(12, 6),
)

# %%
from icl.coin.coin import plot_kl_model_vs_two_bayes_coin_across_k

out = plot_kl_model_vs_two_bayes_coin_across_k(
    k_values=range(5, 14),
    mode="minor",                 # or "train"/"major"/"minor"
    num_samples=2048,
    add_std_band=False,         # True if you want shaded ±1 std
    show=True,
    same_y_axis=True,
    figsize=(12, 6),
)

# %%
from icl.coin.coin import plot_kl_model_vs_two_bayes_coin
from icl.utils.unified_interface import get_exp_name

exp_name = get_exp_name("coin", 7)
out = plot_kl_model_vs_two_bayes_coin(
    exp_name=exp_name,
    modes="minor",
    num_samples=1024,
)

# %%
from icl.coin.analysis.probes import train_linear_hidden_predictor_coin
from icl.utils.unified_interface import get_exp_name

exp_name = get_exp_name("coin", 10)
results = train_linear_hidden_predictor_coin(
    exp_name,
    layer=2,
    B=64,
    n_samples=1000,
    positions = range(1, 25),
    sample_mode = "major",
)
# Out:
# === Fit Summary (layer 2, mode='major') ===
# Model                       Train R²     Val R²      Val MSE
# -----------------------------------------------------------
# Joint (post+tok)              0.6804     0.6777     0.602739
# Posterior only                0.2904     0.2832     1.340705
# Token only                    0.5158     0.5148     0.907481
#
# Partial R²  posterior|token = 0.3358    token|posterior = 0.5504
# F-test  posterior: F=3371.9 p=0.00e+00   token: F=2996.3 p=0.00e+00
# Condition number: 51317636.0
#
#   Design matrix collinearity:
#     Group         dims        VIF  GVIF^(1/2p)   R² from rest
#     -------------------------------------------------------
#     posterior        3       1.27       1.0405         0.2121
#     token            8       1.07       1.0040         0.0620
#
#     Pairwise R²: post↔tok = 0.2121
# MLP val R²: 0.6814  (linear gap = 0.0037)
# Subspace angles (task vs token): mean=45.9°  min=0.0°  max_cos=1.0000  (rank 3 vs 8)
# Component cos(task, token):      mean=0.0992  std=0.1335  |mean|=0.1408

# %%
from icl.coin.analysis.probes import plot_val_r2_across_layers_coin
from icl.utils.unified_interface import get_exp_name

exp_name = get_exp_name("coin", 10)
fig, all_results = plot_val_r2_across_layers_coin(
    exp_name=exp_name,
    n_samples=2**13,
    positions=range(1, 25),
    sample_mode="major",
)
# Out:
# 2026-03-02 22:13:14 - icl.coin.analysis.probes - INFO - [sweep] collecting data for 6 layers in one pass ...
# 2026-03-02 22:13:16 - icl.coin.analysis.probes - INFO - [sweep] fitting layer 0 ...
# 2026-03-02 22:13:50 - icl.coin.analysis.probes - INFO - [sweep] fitting layer 1 ...
# 2026-03-02 22:14:23 - icl.coin.analysis.probes - INFO - [sweep] fitting layer 2 ...
# 2026-03-02 22:14:56 - icl.coin.analysis.probes - INFO - [sweep] fitting layer 3 ...
# 2026-03-02 22:15:30 - icl.coin.analysis.probes - INFO - [sweep] fitting layer 4 ...
# 2026-03-02 22:16:05 - icl.coin.analysis.probes - INFO - [sweep] fitting layer 5 ...
#
# ============================================================
#   Design Matrix Collinearity Summary (layer-independent)
# ============================================================
#   Condition number: 3.79e+07
#   Features: posterior=3  token=8  (total=11)
#
#   Group         dims        VIF  GVIF^(1/2p)   R² from rest
#   -------------------------------------------------------
#   posterior        3       1.26       1.0393         0.2066
#   token            8       1.06       1.0039         0.0599
#
#   Pairwise R² between feature groups:
#     post↔tok = 0.2066
# ============================================================

# %%
from icl.coin.coin_analysis import plot_intervention_across_layers_coin
from icl.utils.unified_interface import get_exp_name

exp_name = get_exp_name("coin", 10)

# Sweep all layers
fig, all_results = plot_intervention_across_layers_coin(
    exp_name=get_exp_name("coin", 10),
    n_ood=64,
    scale=1.0,
    fit_positions=range(1, 25),
    eval_positions=range(1, 25),
    n_samples_eval=1024,
)
# Out:
# 2026-03-02 22:16:40 - icl.coin.analysis.interventions.remove_unigram - INFO - [intervention sweep] layer 0 ...
# 2026-03-02 22:16:43 - icl.coin.analysis.interventions.remove_unigram - INFO - [intervention sweep] layer 1 ...
# 2026-03-02 22:16:46 - icl.coin.analysis.interventions.remove_unigram - INFO - [intervention sweep] layer 2 ...
# 2026-03-02 22:16:48 - icl.coin.analysis.interventions.remove_unigram - INFO - [intervention sweep] layer 3 ...
# 2026-03-02 22:16:51 - icl.coin.analysis.interventions.remove_unigram - INFO - [intervention sweep] layer 4 ...
# 2026-03-02 22:16:54 - icl.coin.analysis.interventions.remove_unigram - INFO - [intervention sweep] layer 5 ...

# %%
from icl.coin.coin_analysis import plot_optimal_orth_direction_across_layers_coin
from icl.utils.unified_interface import get_exp_name

exp_name = get_exp_name("coin", 12)

fig_delta, fig_loss, fig_r2, fig_explained, all_results = plot_optimal_orth_direction_across_layers_coin(
    exp_name=exp_name,
    layers=range(6),
    n_directions=8,
    n_opt_steps=300,
    opt_lr=0.01,
    opt_B=32,
    patience=100,
    grad_clip_norm=0.5,
    n_samples_eval=2**11,
    n_samples_probe=2**10,
    n_ood=128,
    scale=1.0,
    opt_target="minor",
)
# Out:
# 2026-03-02 22:16:57 - icl.coin.analysis.interventions.optimal_orth - INFO - [opt-dir] Phase 1: Fitting probes ...
# 2026-03-02 22:16:59 - icl.coin.analysis.interventions.optimal_orth - INFO - [opt-dir] Phase 2: Loading model & caching eval data ...
# 2026-03-02 22:16:59 - icl.coin.analysis.interventions.optimal_orth - INFO - [opt-dir] Phase 3: Collecting hiddens + unigram ...
# 2026-03-02 22:17:00 - icl.coin.analysis.interventions.optimal_orth - INFO - [opt-dir] Layer 0 ...
# 2026-03-02 22:17:23 - icl.coin.analysis.interventions.optimal_orth - INFO -   layer 0: d_maj=0.0033, d_ood=0.2691, d_minor=0.3296, R²(u→V)=0.379
# 2026-03-02 22:17:23 - icl.coin.analysis.interventions.optimal_orth - INFO - [opt-dir] Layer 1 ...
# 2026-03-02 22:17:46 - icl.coin.analysis.interventions.optimal_orth - INFO -   layer 1: d_maj=0.0023, d_ood=0.3504, d_minor=0.4961, R²(u→V)=0.461
# 2026-03-02 22:17:46 - icl.coin.analysis.interventions.optimal_orth - INFO - [opt-dir] Layer 2 ...
# 2026-03-02 22:18:08 - icl.coin.analysis.interventions.optimal_orth - INFO -   layer 2: d_maj=-0.0003, d_ood=0.1522, d_minor=0.2062, R²(u→V)=0.598
# 2026-03-02 22:18:08 - icl.coin.analysis.interventions.optimal_orth - INFO - [opt-dir] Layer 3 ...
# 2026-03-02 22:18:31 - icl.coin.analysis.interventions.optimal_orth - INFO -   layer 3: d_maj=-0.0003, d_ood=0.2927, d_minor=0.3835, R²(u→V)=0.661
# 2026-03-02 22:18:31 - icl.coin.analysis.interventions.optimal_orth - INFO - [opt-dir] Layer 4 ...
# 2026-03-02 22:18:55 - icl.coin.analysis.interventions.optimal_orth - INFO -   layer 4: d_maj=-0.0005, d_ood=0.1995, d_minor=0.3373, R²(u→V)=0.780
# 2026-03-02 22:18:55 - icl.coin.analysis.interventions.optimal_orth - INFO - [opt-dir] Layer 5 ...
# 2026-03-02 22:19:18 - icl.coin.analysis.interventions.optimal_orth - INFO -   layer 5: d_maj=-0.0004, d_ood=0.2252, d_minor=0.3922, R²(u→V)=0.806

# %%
from icl.coin.coin_analysis import plot_intervention_remove_task_across_layers_coin
from icl.utils.unified_interface import get_exp_name

exp_name = get_exp_name("coin", 12)
fig, results = plot_intervention_remove_task_across_layers_coin(
    exp_name=exp_name,
    eval_positions=range(1, 25),
    fit_positions=range(1, 25),
    n_samples_eval=2048,
    n_ood=512,
    center_task_vecs=True,
)
# Out:
# 2026-03-02 22:19:19 - icl.coin.analysis.interventions.remove_task - INFO - [task-removal sweep] layer 0 ...
# 2026-03-02 22:19:22 - icl.coin.analysis.interventions.remove_task - INFO - [task-removal sweep] layer 1 ...
# 2026-03-02 22:19:25 - icl.coin.analysis.interventions.remove_task - INFO - [task-removal sweep] layer 2 ...
# 2026-03-02 22:19:27 - icl.coin.analysis.interventions.remove_task - INFO - [task-removal sweep] layer 3 ...
# 2026-03-02 22:19:30 - icl.coin.analysis.interventions.remove_task - INFO - [task-removal sweep] layer 4 ...
# 2026-03-02 22:19:32 - icl.coin.analysis.interventions.remove_task - INFO - [task-removal sweep] layer 5 ...

# %%
from icl.coin.coin_analysis import plot_inject_task_vector_across_layers_coin
from icl.utils.unified_interface import get_exp_name

exp_name = get_exp_name("coin", 12)

fig_hm, fig_kl, fig_ood, all_results = plot_inject_task_vector_across_layers_coin(
    exp_name=exp_name,
    layers=range(6),
    n_samples_eval=1024,
    n_ood=64,
    fit_n_samples=4096,
    fit_positions=range(25),           
    eval_positions=range(25),
    center_task_vecs=True,
    scale=1.0,
)
# Out:
# 2026-03-02 22:19:35 - icl.coin.analysis.interventions.inject_task - INFO - [inject sweep] layer 0 ...
# ======================================================================
# Task-Vector Injection  (layer 0, scale=1.0)
# ======================================================================
#   Task subspace rank: 2  |  K_major: 3
#   Ref vecs: from probe W_k - W̄
#
#   Major → Major injection:
#   src→tgt    TaskID acc      KL→t0     KL→t1     KL→t2     ΔLoss
#   ------------------------------------------------------------
#   0→1             5.2%     0.1474    0.1015    0.6939    0.0652
#   0→2            59.0%     0.1905    0.1986    0.3927    0.1403
#   1→0           100.0%     0.3795    0.0360    0.6686    0.2509
#   1→2           100.0%     0.3673    0.0622    0.5067    0.2556
#   2→0             0.0%     0.2931    0.2025    0.3945    0.2353
#   2→1             0.0%     0.3426    0.1513    0.3886    0.1100
#
#   Major → OOD injection:
#   src        TaskID acc      KL→t0     KL→t1     KL→t2     ΔLoss
#   ------------------------------------------------------------
#   0               40.5%     0.2080    0.1998    0.7904    0.0444
#   1              100.0%     0.4682    0.1484    0.8104    0.0121
#   2                0.0%     0.4674    0.3418    0.4996   -0.0066
#
# 2026-03-02 22:19:41 - icl.coin.analysis.interventions.inject_task - INFO - [inject sweep] layer 1 ...
#
# ======================================================================
# Task-Vector Injection  (layer 1, scale=1.0)
# ======================================================================
#   Task subspace rank: 2  |  K_major: 3
#   Ref vecs: from probe W_k - W̄
#
#   Major → Major injection:
#   src→tgt    TaskID acc      KL→t0     KL→t1     KL→t2     ΔLoss
#   ------------------------------------------------------------
#   0→1            88.8%     0.0799    0.1699    0.7685    0.1505
#   0→2            95.8%     0.0874    0.2190    0.6376    0.2590
#   1→0           100.0%     0.3539    0.0312    0.6771    0.2300
#   1→2           100.0%     0.3593    0.0562    0.5754    0.2921
#   2→0            88.2%     0.3259    0.3035    0.1945    0.3005
#   2→1            85.2%     0.3779    0.2940    0.1679    0.2631
#
#   Major → OOD injection:
#   src        TaskID acc      KL→t0     KL→t1     KL→t2     ΔLoss
#   ------------------------------------------------------------
#   0               92.5%     0.2393    0.2779    0.8983    0.0419
#   1              100.0%     0.4914    0.1765    0.8402   -0.0026
#   2               63.7%     0.4984    0.4021    0.3899    0.0516
#
# 2026-03-02 22:19:46 - icl.coin.analysis.interventions.inject_task - INFO - [inject sweep] layer 2 ...
#
# ======================================================================
# Task-Vector Injection  (layer 2, scale=1.0)
# ======================================================================
#   Task subspace rank: 2  |  K_major: 3
#   Ref vecs: from probe W_k - W̄
#
#   Major → Major injection:
#   src→tgt    TaskID acc      KL→t0     KL→t1     KL→t2     ΔLoss
#   ------------------------------------------------------------
#   0→1            94.0%     0.0481    0.2109    0.8212    0.2188
#   0→2           100.0%     0.0428    0.2284    0.7710    0.3307
#   1→0           100.0%     0.3190    0.0335    0.7000    0.1993
#   1→2           100.0%     0.3503    0.0276    0.6794    0.3687
#   2→0            99.0%     0.4010    0.3740    0.0850    0.4252
#   2→1            96.2%     0.4378    0.3960    0.0691    0.4174
#
#   Major → OOD injection:
#   src        TaskID acc      KL→t0     KL→t1     KL→t2     ΔLoss
#   ------------------------------------------------------------
#   0               99.2%     0.1969    0.2939    0.9087    0.0527
#   1              100.0%     0.4489    0.1717    0.8238    0.0028
#   2               93.0%     0.5315    0.4667    0.3148    0.0856
#
# 2026-03-02 22:19:52 - icl.coin.analysis.interventions.inject_task - INFO - [inject sweep] layer 3 ...
#
# ======================================================================
# Task-Vector Injection  (layer 3, scale=1.0)
# ======================================================================
#   Task subspace rank: 2  |  K_major: 3
#   Ref vecs: from probe W_k - W̄
#
#   Major → Major injection:
#   src→tgt    TaskID acc      KL→t0     KL→t1     KL→t2     ΔLoss
#   ------------------------------------------------------------
#   0→1           100.0%     0.0356    0.2195    0.8071    0.2121
#   0→2           100.0%     0.0405    0.2145    0.7263    0.3071
#   1→0           100.0%     0.3536    0.0109    0.7182    0.2234
#   1→2           100.0%     0.3644    0.0136    0.6917    0.3695
#   2→0           100.0%     0.4106    0.3702    0.0662    0.4203
#   2→1           100.0%     0.4530    0.4099    0.0393    0.4453
#
#   Major → OOD injection:
#   src        TaskID acc      KL→t0     KL→t1     KL→t2     ΔLoss
#   ------------------------------------------------------------
#   0              100.0%     0.1753    0.2939    0.9343    0.0551
#   1              100.0%     0.4548    0.1312    0.8175    0.0084
#   2              100.0%     0.5379    0.4551    0.2541    0.1088
#
# 2026-03-02 22:19:57 - icl.coin.analysis.interventions.inject_task - INFO - [inject sweep] layer 4 ...
#
# ======================================================================
# Task-Vector Injection  (layer 4, scale=1.0)
# ======================================================================
#   Task subspace rank: 2  |  K_major: 3
#   Ref vecs: from probe W_k - W̄
#
#   Major → Major injection:
#   src→tgt    TaskID acc      KL→t0     KL→t1     KL→t2     ΔLoss
#   ------------------------------------------------------------
#   0→1           100.0%     0.0276    0.2203    0.8371    0.2161
#   0→2           100.0%     0.0209    0.2346    0.8271    0.3695
#   1→0           100.0%     0.3436    0.0104    0.7129    0.2184
#   1→2           100.0%     0.3599    0.0106    0.6992    0.3816
#   2→0           100.0%     0.4427    0.4044    0.0354    0.4822
#   2→1           100.0%     0.4458    0.3943    0.0385    0.4005
#
#   Major → OOD injection:
#   src        TaskID acc      KL→t0     KL→t1     KL→t2     ΔLoss
#   ------------------------------------------------------------
#   0              100.0%     0.2028    0.2964    0.9616    0.0682
#   1              100.0%     0.4854    0.1452    0.8410   -0.0035
#   2              100.0%     0.5541    0.4402    0.2060    0.1525
#
# 2026-03-02 22:20:02 - icl.coin.analysis.interventions.inject_task - INFO - [inject sweep] layer 5 ...
#
# ======================================================================
# Task-Vector Injection  (layer 5, scale=1.0)
# ======================================================================
#   Task subspace rank: 2  |  K_major: 3
#   Ref vecs: from probe W_k - W̄
#
#   Major → Major injection:
#   src→tgt    TaskID acc      KL→t0     KL→t1     KL→t2     ΔLoss
#   ------------------------------------------------------------
#   0→1           100.0%     0.0212    0.2335    0.8330    0.2401
#   0→2           100.0%     0.0181    0.2337    0.8074    0.3552
#   1→0           100.0%     0.3551    0.0093    0.7005    0.2175
#   1→2           100.0%     0.3565    0.0101    0.6824    0.3669
#   2→0           100.0%     0.4561    0.4086    0.0182    0.5446
#   2→1           100.0%     0.4587    0.4095    0.0192    0.4339
#
#   Major → OOD injection:
#   src        TaskID acc      KL→t0     KL→t1     KL→t2     ΔLoss
#   ------------------------------------------------------------
#   0              100.0%     0.1618    0.3106    0.9741    0.0919
#   1              100.0%     0.4687    0.1180    0.8160    0.0178
#   2              100.0%     0.5804    0.4953    0.1103    0.2269

# %%
from icl.coin.coin_analysis import traj_post_posterior_projection_plot_coin
from icl.utils.unified_interface import get_exp_name

exp_name = get_exp_name("coin", -1)
result = traj_post_posterior_projection_plot_coin(
    exp_name=exp_name,
    layer_index=5,
    task_ids=range(5),
    B=32,
)

# %%
from icl.coin.coin_analysis import plot_lambda_posterior_agreement_coin
from icl.utils.unified_interface import get_exp_name

exp_name = get_exp_name("coin", -1)
result = plot_lambda_posterior_agreement_coin(
    exp_name=exp_name,
    layer_index=5,
    n_ood=32,
)
# Out:
# C:\Users\User\LLM\mini-ICL\src\icl\coin\analysis\posterior.py:678: RuntimeWarning: Mean of empty slice
#   rcorr_per_task[k] = np.nanmean(sample_corrs, axis=0)
# C:\Users\User\LLM\mini-ICL\src\icl\coin\analysis\posterior.py:680: RuntimeWarning: Mean of empty slice
#   rcorr_major = np.nanmean(rcorr_per_task[:k_major], axis=0)
# C:\Users\User\LLM\mini-ICL\src\icl\coin\analysis\posterior.py:681: RuntimeWarning: Mean of empty slice
#   rcorr_ood = np.nanmean(rcorr_per_task[k_major:], axis=0)

# %%
from icl.coin.coin_analysis import traj_posterior_projection_plot_coin
from icl.utils.unified_interface import get_exp_name

exp_name = get_exp_name("coin", -1)
result = traj_posterior_projection_plot_coin(
    exp_name=exp_name,
    layer_index=5,
    n_ood=64,
    n_minor=0,
    annotate=False,
)

# %%
exp_name = get_exp_name("coin", 11)
result = traj_posterior_projection_plot_coin(
    exp_name=exp_name,
    layer_index=5,
    n_ood=32,
    n_minor=32,
    annotate=False,
)
